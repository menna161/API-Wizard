# %% [markdown]
# # Source: https://ucb-sejits.github.io/ctree-docs/ipythontips.html

# %%
# !pip install ipython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.6 MB 4.3 MB/s
# ...

# %%
# !cd $CTREE

# %%
pip install ctree
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 KB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 KB 5.6 MB/s eta 0:00:00
# ...
#   Created wheel for ctree: filename=ctree-0.1.9-py3-none-any.whl size=58180 sha256=47ce5e2dfcdbc8905994fa9cc2ab08f89e98365429dd1f741dca1cf191f8a6e1
#   Stored in directory: /root/.cache/pip/wheels/7c/b4/9d/3235c21f23b3c3d2b1b8b9824852c88c418ab04fdfceaf05db
# Successfully built ctree
# ...

# %%
import ctree

def f(a):
    x = txt.split()
    print(x)

def g(a):
  regression = LinearRegression()
  regression.fit(x_training, y_training)

tree1 = ctree.get_ast(f)
ctree.ipython_show_ast(tree1)

# %%
import ctree


def ex1(a):
  for line in content.split('.'):
    print(line)


tree1 = ctree.get_ast(ex1)
ctree.ipython_show_ast(tree1)
# Out:
#   File "<ipython-input-7-da50ff8b4414>", line 6
#     print(x))
#             ^
# SyntaxError: invalid syntax
